# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, auc, roc_curve, confusion_matrix, plot_confusion_matrix, f1_score
from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from statistics import mean 

import matplotlib.pyplot as plt
import seaborn as sn

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
DATA_DIR = '../data/'
TOOLS_DIR = '../tools/'
FILENAME = 'AllDiscussionDataCODED_USE_THIS_14Feb2020_MH.xls'
LEMMASFILETRAIN = DATA_DIR + 'train.output'
LEMMASFILETEST = DATA_DIR + 'test.output'

data = pd.read_excel( io = DATA_DIR + FILENAME ).dropna('index', 'all').dropna('columns', 'all')
# data = data.reset_index()
with open( DATA_DIR + 'stopwords-sl.txt', mode='r', encoding='utf-8') as f:
    stopwordsSLO = f.read().split( '\n' )

# %%
def parseLemmas( filename , additional=False):
    lemmas = []
    forbidden = {'.', ',', '!', '?', '»', '«', '—', '(', ')', '...', '-'}
    with open( filename, mode = 'r', encoding ='utf-8' ) as f:
        for l in f.readlines():
            line = l.strip()
            if line.startswith( '#' ):
                if line.startswith( '# newpar id =' ):
                    lemmas.append( [ ] )
                else:
                    continue
            tmp = line.split( '\t' )
            if len( tmp ) > 1:
                result = tmp[2].lower()
                if not additional:
                    lemmas[ -1 ].append(result)
                else:
                    if not result in forbidden:
                        lemmas[ -1 ].append(result)
                    else:
                        lemmas[-1].append('')
#     return pd.Series( lemmas, indexes )
    return lemmas

def writeMessages( msgs, filename ):
    with open( DATA_DIR + filename + '.input', 'w', encoding='utf-8' ) as f:
        for line in msgs:
            f.write( str( line ) + '\n' )

def prepareTokens( filename ):
    command = 'cat {0}{3}.input | python {1}tokeniser.py sl -n -c -d > {2}'.format( DATA_DIR, TOOLS_DIR + 'reldi-tokeniser-master/', DATA_DIR + filename + '.conllu', filename )
    print( 'Running command ', command )
    # !$command
    
def prepareLemmas( filename ):
    command = 'cd {0} python -m stanfordnlp.models.lemmatizer --model_dir models/lemma/ --model_file ssj500k+Sloleks --eval_file {1} --output_file {2} --mode predict; cd --;'.format( '../tools/classla-stanfordnlp-master;', '../../data/' + filename + '.conllu', '../../data/' + filename + '.output' )
    # !$command
    
def lemmatize( messages, filename ): # filename without endings
#     filename = 'train' if train else 'test'
    
    writeMessages( messages, filename )
    prepareTokens( filename )
    prepareLemmas( filename )
    lemmas = parseLemmas( DATA_DIR + filename + '.output' )
    return lemmas

# %%
class LemmaTokenizer( object ):
    def __init__( self ):
        self.wnl = WordNetLemmatizer()
        
    def __call__( self, articles ):
#         print( articles )
        return articles
#         return [ self.wnl.lemmatize( t ) for t in word_tokenize( articles ) if self.wnl.lemmatize( t ) not in stopwordsSLO ]

# %%
data.drop( data[ pd.isna( data[ 'Message' ] ) == True ].index, inplace = True ) # remove rows with empty message
data.drop( data[ pd.isna( data[ 'Book relevance' ] ) == True ].index, inplace = True ) # remove rows with unknown book relevance

# some additional preprocessing

# %%
butalci = []
with open( DATA_DIR + 'butalski.txt', mode = 'r', encoding = 'utf-8' ) as f:
    for line in f.readlines():
        butalci.append( line.strip() )
        
vevericek = []
with open( DATA_DIR + 'vevericek.txt', mode = 'r', encoding = 'utf-8' ) as f:
    for line in f.readlines():
        vevericek.append( line.strip() )
        
premrazeno = []
with open( DATA_DIR + 'premrazeno.txt', mode = 'r', encoding = 'utf-8' ) as f:
    for line in f.readlines():
        premrazeno.append( line.strip() )

lemmasButalci = parseLemmas( DATA_DIR + 'butalci.output' , True) # lemmatize( butalci, 'butalci' )
print( len( lemmasButalci ) )

lemmasVevericek = parseLemmas( DATA_DIR + 'vevericek.output' , True ) # lemmatize( vevericek, 'vevericek' )
print( len( lemmasVevericek ) )

lemmasPremrazeno = parseLemmas( DATA_DIR + 'premrazeno.output', True ) # lemmatize( premrazeno, 'premrazeno' )
print( len( lemmasPremrazeno ) )
# Out:
# 16
# 52
# 31

# %%
# print( len( data[ pd.isna( data[ 'Message' ] ) == True ] ) )
# print( len( data[ pd.isna( data[ 'Book relevance' ] ) == True ] ) )
X_trainO, X_testO, y_trainO, y_testO = train_test_split( data[ 'Message' ], data[ 'Book relevance' ], random_state = 42 )
# writeMessages( X_trainO )
# prepareTokens()
# prepareLemmas()



# lemmas = lemmatize( X_trainO, 'train' )
# lemmas = lemmatize( X_testO, 'test' )

# %%
lemmasTrain = parseLemmas( LEMMASFILETRAIN )
lemmasTest = parseLemmas( LEMMASFILETEST )

# %%
x_relevant = len( X_trainO[ ( data[ 'Book relevance' ] == 'Yes' ) ] )
x_nonrelevant = len( X_trainO[ ( data[ 'Book relevance' ] == 'No' ) ] )
testNonRelevant = len( X_testO[ ( data[ 'Book relevance' ] == 'No' ) ] )
print( 'Book relevant texts in training set: {0}'.format( x_relevant ) )
print( 'Book non-relevant texts in training set: {0}'.format( x_nonrelevant ) )
print( 'Baseline classifier accuracy on training set: {0}'.format( x_nonrelevant / len( X_trainO ) ) )
print( 'Baseline classifier accuracy on test set: {0}'.format( testNonRelevant / len( X_testO ) ) )
# Out:
# Book relevant texts in training set: 1047
# Book non-relevant texts in training set: 1606
# Baseline classifier accuracy on training set: 0.605352431209951
# Baseline classifier accuracy on test set: 0.6192090395480226

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
import numpy as np
import random

class MeasureFeatures(BaseEstimator):

    def __init__(self, type):
        self.problem_type = type
        pass

    def longest_repeat(self, s):
        maximum = count = 0
        current = ''
        for c in s:
            if c == current:
                count += 1
            else:
                count = 1
                current = c
            maximum = max(count,maximum)
        return maximum
    
    def get_feature_names(self):
        return np.array(['longest_word', #'contains_question_mark', 'contains_exclamation_mark', 
                         'longest_repeatance'])

    def fit(self, documents, y=None):
        return self

    def transform(self, x_dataset):
        X = None
        if self.problem_type == 'book_relevance':
            print("BOOK RELEVANCE...")
            X_length = list()
            X_longest_repeatance = list()
            X_discussion = list()
            discussion = ['lahko']

            for words in x_dataset:
                #print(words)

                X_length.append(1 if max(len(w) for w in words) > 12 else 0)
                X_longest_repeatance.append(1 if max(self.longest_repeat(w) for w in words) > 4 else 0)
                discussion_count = len([s for s in words if any(xs in s for xs in discussion)])
                X_discussion.append(1 if discussion_count > 0 else 0)


            X = np.array([X_length, X_longest_repeatance, X_discussion]).T
            
        elif self.problem_type == 'type':
            print("TYPE...")
            questions = ['kje', 'kdaj', 'kako', 'kam', 'zakaj', 'čemu', 'cemu', 'kaj', 'komu', 'kdo', '?']
            
            X_questions= list()
            #X_be = list()

            for words in x_dataset:
                
                question_count = len([s.lower() for s in words if any(xs in s for xs in questions)])
                #Better if 0 or 1
                X_questions.append(1 if question_count > 0 else 0)            

            X = np.array([X_questions#, X_be
                         ]).T
        elif self.problem_type == 'category_broad':
            print("TYPE...")
        
            #IDENTITY
            identity = ['kdo', 'jaz', 'ime']
            X_identity = list()
        
            #CHATTING
            X_longest_repeatance = list()
            X_length = list()

            #DISCUSSION
            discussion = ['lahko'  'bi']
            X_discussion = list()
            
            #MODERATING
            #X_moderating = list()

            for words in x_dataset:
                #print(words)
                
                identity_count = len([s for s in words if any(xs in s for xs in identity)])
                #Better if 0 or 1
                X_identity.append(1 if identity_count > 0 else 0)           
                
                X_length.append(1 if max(len(w) for w in words) > 12 else 0)
                X_longest_repeatance.append(1 if max(self.longest_repeat(w) for w in words) > 4 else 0)
                
                #X_moderating.append(1 if max(w.find(",") for w in words) != -1 else 0)
                
                discussion_count = len([s for s in words if any(xs in s for xs in discussion)])
                X_discussion.append(1 if discussion_count > 0 else 0)
                
            X = np.array([X_identity, X_longest_repeatance, X_length, 
                          X_discussion]).T
            

        if not hasattr(self, 'scalar'):
            self.scalar = StandardScaler().fit(X)
        return self.scalar.transform(X)

# %%
cv = FeatureUnion([
    ('tfidf', TfidfVectorizer(tokenizer = lambda x : x, preprocessor = lambda x : x, analyzer = 'word', sublinear_tf=True, max_df=0.5)),
    ('feat', MeasureFeatures('book_relevance'))
                  ])


X_train = np.array( [ value for value in X_trainO ], dtype = str )
y_train = np.array( [ value for value in y_trainO ], dtype = str )


def append_lemmas(lemmasExtended, y, lemmasToAdd):
    sub_array = []
    for array in lemmasToAdd:
        print(str(array))
        lemmasExtended.append(array)
        sub_array.append('Yes')
    y = np.append(y_train, np.array(sub_array))
    return lemmasExtended, y
    
lemmasTrainExtended = list(lemmasTrain)
lemmasTrainExtended, y_train = append_lemmas(lemmasTrainExtended, y_train, lemmasButalci)
lemmasTrainExtended, y_train = append_lemmas(lemmasTrainExtended, y_train, lemmasVevericek)
lemmasTrainExtended, y_train = append_lemmas(lemmasTrainExtended, y_train, lemmasPremrazeno)

X_test = np.array( [ value for value in X_testO ], dtype = str )
y_test = np.array( [ value for value in y_testO ], dtype = str )

# X_train_cv = cv.fit_transform( X_train.values.astype( 'U' ) )
# X_test_cv = cv.transform( X_test.values.astype( str ) )


# cv = CountVectorizer( tokenizer = lambda x : x, preprocessor = lambda x : x, stop_words = stopwordsSLO )

#THIS ONE WAS BEFORE
#cv = CountVectorizer( tokenizer = lambda x : x, preprocessor = lambda x : x, analyzer = 'word', ngram_range = ( 1, 3 ) )

X_train_cv = cv.fit_transform( lemmasTrainExtended )
X_test_cv = cv.transform( lemmasTest )

# X_train_cv = cv.fit_transform( X_train )
# X_test_cv = cv.transform( X_test )


# word_freq_df = pd.DataFrame( X_train_cv.toarray(), columns = cv.get_feature_names() )
# top_words_df = pd.DataFrame( word_freq_df.sum() ).sort_values( 0, ascending = False )
# print( top_words_df )
# Out:
# ['\ufeff', '1.', 'milčinski', '', 'fran', 'butalski', 'policaj', 'in', 'cefizelj', '', '5.', 'r.', '']
# ['bitj', 'ni', 'ono', 'stran', 'lež', 'vas', '', 'se', 'ji', 'pravi', 'butale', '', 'butalec', 'so', 'gadji', ';', 'tisti', 'leto', '', 'koj', 'sta', 'biti', 'dve', 'kravi', 'za', 'en', 'par', '', 'so', 'se', 'butalec', 'skregati', 's', 'pametji', '', 'pa', 'so', 'zmagal', 'butalec', 'in', 'ni', 'pamet', 'biti', 'takšen', 'so', '']
# ['v', 'butalah', 'so', 'imeti', 'občinski', 'hlapec', '', 'ob', 'delavnik', 'je', 'goved', 'pasel', 'in', 'lenob', '', 'ob', 'nedelja', 'in', 'praznik', 'pa', 'si', 'je', 'ni', 'glav', 'povezniti', 'kap', '', 'ta', 'kap', 'je', 'biti', 'rdeče', 'obšit', '', 'v', 'rok', 'je', 'vzeti', 'helebardo', 'ali', 'sulic', 'in', 'je', 'bil', 'policaj', '', 'strah', 'vse', 'tolovajev', '', 'o', 'ta', 'policaj', 'je', 'slišal', 'tudi', 'grozanski', 'razbojnik', 'cefizelj', '', 'ki', 'so', 'praviti', '', 'da', 'je', 'že', 'sedem', 'ljud', 'zadušiti', 'in', 'trije', 'ženski', '', 'pa', 'je', 'zasrbel', 'cefizelj', '', 'da', 'si', 'gre', 'ogledat', 'policaj', '', 'in', 'je', 'biti', 'tisti', 'nedelji', '', 'koj', 'obhajaj', 'v', 'butalah', 'vsakoleten', 'žegnanji', 'in', 'poboj', '', 'pa', 'je', 'šel', 'v', 'butale', 'in', 'se', 'nastaviti', 'policaj', 'tik', 'pod', 'nos', '']
# ['policaj', 'je', 'rekel', 'biti', '', 'hop', '', 'cefizelj', '', 'ti', 'že', 'imeti', '', 'marš', 'v', 'luknji', '', 'imeti', 'krojač', '', 'se', 'mu', 'pravi', 'rabelj', '', 'ti', 'bo', 'vzeti', 'mero', 'okrog', 'vrat', '', '', 'cefizelj', 'ni', 'rekel', 'ni', 'bev', 'ni', 'mev', 'in', 'je', 'šel', 's', 'policaj', '', 'pa', 'pridet', 'mimo', 'pekaj', '']
# ['', 'oh', '', '', 'je', 'vzdihniti', 'cefizelj', '', '', 'dokler', 'še', 'lahko', 'požira', ';', 'en', 'samo', 'edin', 'koruzen', 'hlebček', 'bi', 'rad', 'snedel', '', 'tako', 'dober', '', 'praviti', '', 'ni', 'peko', 'nikjer', 'nikoder', 'kakor', 'v', 'butalah', '', '']
# ['', 'n', '', '', 'je', 'pritrdil', 'policaj', '', '', 'pri', 'nas', 'imamo', 'masten', 'gnoj', '', 'naš', 'mok', 'iz', 'naš', 'koruz', 'je', 'kakor', 'zabeljen', '', '']
# ['in', 'kar', 'je', 'bil', 'pek', 'za', 'občinski', 'mož', '', '', 'mu', 'policaj', 'ni', 'marati', 'odjest', 'dobiček', 'in', 'je', 'pustil', 'cefizelj', 'v', 'pekarij', 'in', 'se', 'je', 's', 'helebardo', 'ali', 'sulic', 'postaviti', 'pred', 'vrat', '', 'da', 'ga', 'počak', '', 'čak', 'in', 'čak', '', 'pa', 'ga', 'ni', 'biti', 'cefizelj', '', 'šent', 'je', 'bil', 'odšel', 'pri', 'zadnji', 'vrat', 'in', 'se', 'nit', 'ni', 'posloviti', '', 'policaj', 'hud', '', 'krščen', 'matiček', '', 'tako', 'je', 'bil', 'hud', '', 'da', 'je', 'kar', 'pljuniti', '', 'ali', 'cefizelj', 'ni', 'biti', 'in', 'ga', 'ni', 'biti', 'in', 'ni', 'vse', 'nič', 'pomagati', '']
# ['poteč', 'teden', '', 'potečeti', 'dva', '', 'pride', 'tretji', 'nedelj', '', 'pa', 'je', 'cefizelj', 'spet', 'zasrbel', '', 'da', 'gre', 'v', 'butale', '', 'in', 'je', 'šel', 'in', 'se', 'nastaviti', 'policaj', 'pod', 'nos', '']
# ['', 'hop', '', '', 'je', 'rekel', 'policaj', '', '', 'ali', 'ti', 'imeti', '', 'zdaj', 'mi', 'več', 'ni', 'uideš', '', '', 'in', 'ga', 'je', 'prijel', 'za', 'rokav', '']
# ['cefizelj', 'je', 'prositi', 'zamere', 'biti', '', 'tujec', 'samo', '', '', 'je', 'rekel', '', '', 'deželan', '', 'pa', 'samo', 'zadnjič', 'pot', 'zgrešiti', 'od', 'pekaj', '', 'da', 'vas', 'nis', 'našel', '', 'ali', 'mi', 'je', 'biti', 'malo', 'hud', '', '', '', 'in', 'je', 'šel', 's', 'policaj', 'kakor', 'jagnji', 'za', 'materji', '']
# ['pa', 'pridet', 'mimo', 'pekaj', 'in', 'cefizelj', 'se', 'je', 'spomniti', '', 'da', 'je', 'lačen', '', 'in', 'je', 'lep', 'prositi', 'in', 'policaj', 'ga', 'je', 'spustiti', 'v', 'pekarij', ';', 'misliti', 'si', 'je', 'biti', '', 'ti', 'si', 'zvit', '', 'jaz', 'pa', 'se', 'bolj', '', 'to', 'pot', 'mi', 'ni', 'uideš', '', '', 'in', 'se', 'je', 'postaviti', 'ni', 'zadnji', 'vrat', '', 'in', 'je', 'čakal', 'in', 'čakal', '', 'pa', 'ni', 'dočakati', '', 'kar', 'je', 'cefizelj', 'to', 'pot', 'šel', 'zbog', 'pri', 'sprednjih', 'dur', ';', 'in', 'je', 'bil', 'policaj', 'sil', 'hud', '', 'malo', 'je', 'manjkati', '', 'da', 'ni', 'zaklel', '']
# ['poteč', 'trije', 'teden', 'pa', 'cefizelj', 'spet', 'v', 'butale', 'in', '', 'policaj', 'pod', 'nos', '']
# ['', 'hop', '', '', 'je', 'rekel', 'policaj', '', '', 'ali', 'ti', 'imeti', '', 'jaz', 'ti', 'pokazaj', '', 'kaj', 'je', 'butalski', 'policaj', '', 'da', 'mu', 'biti', 'uhajati', '', '', 'in', 'ga', 'je', 'prijel', 'za', 'rokav', '']
# ['cefizelj', 'je', 'prositi', 'zamere', 'biti', '', 'ni', 'vas', 'biti', 'pred', 'vrat', '', '', 'je', 'rekel', '', '', 'pa', 'samo', 'vas', 'iskal', '', 'kje', 'ste', ';', 'do', 'današnji', 'dne', 'samo', 'vas', 'iskal', 'in', 'do', 'tele', 'ure', '', '', 'in', 'je', 'šel', 's', 'policaj', 'in', 'se', 'ni', 'nič', 'braniti', '']
# ['pridet', 'mimo', 'pekaj', 'in', 'si', 'je', 'cefizelj', 'spet', 'zmisliti', '', 'da', 'bi', 'šel', 'noter', 'in', 'si', 'kupiti', 'koruzen', 'hlebček', '', 'in', 'je', 'milo', 'prositi', '', 'da', 'nihče', 'ta', '', 'pa', 'je', 'rekel', 'policaj', 'biti', '', 'tiček', 'ti', '', 'bi', 'mi', 'spet', 'rad', 'uiel', '', 'pri', 'tisti', 'dur', '', 'ni', '', 'kjer', 'mene', 'ni', 'bo', '', 'ni', 'biti', '', 'jak', '', 'daj', 'semkaj', 'groš', '', 'grije', 'samo', 'kupit', 'koruzen', 'hlebček', '', 'pa', 'me', 'ti', 'čakaj', 'tukajti', '', '']
# ['in', 'je', 'policaj', 'šel', 'in', 'kupiti', 'in', 'prišel', 'nazaj', 'in', 'koj', 'je', 'hotel', 'cefizelj', 'dati', 'hlebček', '', 'ni', 'biti', 'več', 'cefizelj', '', 'in', 'je', 'bil', 'policaj', 'tako', 'jezen', '', 'da', 'je', 'jezik', 'pokazal', 'za', 'cefizelj', '', 'in', 'je', 'še', 'dobro', '', 'da', 'cefizelj', 'ta', 'ni', 'videl', ';', 'zakaj', 'cefizelj', 'je', 'bil', 'grozanski', 'ropar', '', 'ki', 'so', 'praviti', '', 'da', 'je', 'že', 'sedem', 'ljud', 'zadušiti', 'in', 'pa', 'trije', 'ženski', '']
# ['\ufeff', 'veveriček', 'poseben', 'sorte']
# ['makarovič', '', 'svetlan', 'že', 'v', 'začetek', 'strašen', 'srečanje', 'z', 'oblakom1', ';', 'veveriček', 'poseben', 'sorte2', '', '4.', 'r.', '']
# ['tih', 'aprilski', 'dež', 'je', 'rositi', 'ni', 'smrekovji', 'veveričje', 'gaj', '', 'koj', 'je', 'v', 'rano', 'jutro', 'zavreščal', 'šoj', 'biti', '', 'novic', '', 'velik', 'novic', '', 'veveric', 'puhank', 'je', 'postal', 'mama', '', 'skotil', 'je', 'pet', 'mladičkov', '', '']
# ['on', 'ni', 'novic', 'v', 'gozd', '', 'veste', '', 'ki', 'bi', 'je', 'šoj', 'ni', 'izvedeti', 'prvi', '', 'in', 'seveda', 'je', 'moral', 'tudi', 'tale', 'pri', 'priči', 'razkričati', 'naokrog', '', 'zajčji', 'družin', 'je', 'vesel', 'zamrdati', 'z', 'gobček', 'biti', 'kar', 'pet', 'nov', 'veveric', '', 'imeniten', '', 'le', 'brž', 'naj', 'zrastej', '', 'da', 'se', 'bomo', 'lahko', 'skupaj', 'lovil', 'pa', 'skrivati', '']
# ['pa', 'ni', 'samo', 'zajci', '', 'tudi', 'miški', '', 'ki', 'so', 'velik', 'prijateljice', 'veveric', '', 'so', 'se', 'silen', 'razveselile', 'in', 'radoveden', 'opazovale', 'pod', 'košat', 'smrek', '', 'kjer', 'si', 'je', 'biti', 'uredil', 'puhank', 'prijetno', 'bivališče', 'v', 'topel', 'duplin', 'visok', 'v', 'krošnji', '']
# ['puhank', '', 'ki', 'so', 'se', 'k', 'on', 'pritiskati', 'mladički', '', 'še', 'vsi', 'gol', 'in', 'nebogljen', '', 'je', 'seveda', 'slišal', 'navdušen', 'klice', 'od', 'zunaj', '', 'zadovoljno', 'je', 'mežikati', 'in', 'si', 'predstavljati', '', 'kak', 'vesel', 'bo', '', 'koj', 'biti', 'ta', 'njen', 'neroden', 'kepica', 'zrasti', 'puhast', 'kožuščki', 'in', 'košat', 'repki', ';', 'koj', 'se', 'biti', 'njihov', 'črne', 'očke', 'odprle', 'in', 'se', 'radoveden', 'razgledale', 'naokrog', '', 'in', 'takrat', 'šele', '', 'takrat', '', 'koj', 'biti', 'dovolj', 'krepki', 'za', 'prvi', 'skok', 'ni', 'bližnji', 'drevo', '', 'in', 'koj', 'biti', 'znali', 'z', 'ostal', 'zobek', 'že', 'mojstrski', 'oglodat', 'storž', 'in', 'ga', 'spretno', 'zalučat', 'tako', '', 'da', 'bo', 'priletel', 'raven', 'lisic', 'ni', 'buč', '', 'oh', '', 'kak', 'bo', 'mama', 'puhank', 'ponosen', '']
# ['tekel', 'so', 'dnevi', '', 'veveričke', 'so', 'rasle', 'in', 'se', 'krepile', '', 'trije', 'veverički', 'in', 'dve', 'veveric', 'so', 'se', 'prerivati', 'in', 'kobacati', 'po', 'duplin', 'in', 'potem', '', 'potem', 'je', 'nek', 'sončen', 'juter', 'repepk', 'veveriček', 'pokukati', 'ni', 'plan', 'in', 'se', 'splazil', 'ni', 'veti', '']
# ['nekaj', 'čas', 'je', 'osuplo', 'zijal', 'okol', 'sebe', '', 'potem', 'pa', 'je', 'nenadoma', 'začutil', 'v', 'droben', 'tele', 'silen', 'želj', 'po', 'gibanji', '', 'in', 'samo', 'ni', 'vedel', '', 'kdaj', 'in', 'kak', '', 'pa', 'se', 'je', 'že', 'odgnati', 'in', 'v', 'dolg', 'skok', 'pristati', 'ni', 'veli', 'bližnji', 'bukve', '']
# ['', 'hej', '', 'juh', '', '', 'je', 'zacvilil', 'in', 'se', 'vesel', 'zahihital', '', '', 'si', 'me', 'videti', '', 'mama', '', 'ste', 'me', 'videti', '', 'vi', 'vsi', '', 'hu', '', 'kak', 'samo', 'skočiti', '', '']
# ['mam', 'puhank', 'je', 'biti', 'spočetek', 'nekolik', 'zaskrbljen', '', 'kot', 'pač', 'vse', 'mame', '', 'zmajevati', 'je', 'z', 'glav', 'in', 'klicati', 'biti', '', 'previden', '', 'otroci', '', 'previdno', '', '', 'zraven', 'pa', 'jo', 'je', 'seveda', 'kar', 'razganjati', 'od', 'ponos', '', 'koj', 'sta', 'se', 'ojunačiti', 'še', 'obe', 'veverički', 'in', 'kar', 'poletel', 'ni', 'bližnji', 'drevo', '']
# ['potlej', 'se', 'je', 'odgnati', 'še', 'bratec', '', 'hop', '', 'ta', 'je', 'biti', 'smeh', 'in', 'vesel', 'vzklikanje', '', 'ampak', '']
# ['ampak', 'majhen', 'veveriček', 'je', 'še', 'kar', 'čepel', 'ni', 'veli', 'pred', 'domač', 'duplin', 'in', 'se', 'neroden', 'prekladati', 'samo', 'in', 'ti', '']
# ['', 'no', '', 'čopek', '', '', 'je', 'zaklicati', 'mama', '', '', 'kar', 's', 'korajže', '', '']
# ['čopek', 'je', 'negotov', 'pogledati', 'mamo', '', 'potlej', 'pa', 'navzdol', '', 'kjer', 'so', 'ni', 'jas', '', 'globok', 'globok', 'spodaj', 'že', 'čakati', 'štirje', 'zajčki', 'in', 'ga', 'spodbujati', '', 'naj', 'že', 'tvi', 'prvi', 'skok', '']
# ['', 'ni', 'vem', '', 'ni', 'vem', '', 'kak', 'naj', 'skoč', '', '', 'je', 'negotov', 'zamrmrati', 'čopek', '', '', 'noben', 'moči', 'ni', 'čut', 'v', 'tačka', '', '']
# ['', 'daj', 'no', '', '', 'ga', 'je', 'pokarati', 'puhank', '', '', 'menda', 'mi', 'ni', 'biti', 'narediti', 'sramote', 'pred', 'ves', 'gozd', 's', 'svoj', 'strahopetnost', '', '']
# ['čopek', 'jo', 'je', 'prestrašen', 'pogledati', 'in', 'se', 'poskušati', 'pripraviti', 'ni', 'skok', '', 'pa', 'ga', 'je', 'nekak', 'čudno', 'zanesel', '', 'in', 'če', 'se', 'ni', 'bi', 'bil', 'zadnji', 'hip', 'ujel', 's', 'sprednji', 'šapic', 'za', 'veti', '', 'bi', 'kar', 'strmoglaviti', 'v', 'globin', '']
# ['mam', 'je', 'priskakljati', 'k', 'on', '']
# ['', 'kaj', 'pa', 'se', 'to', 'pravi', '', 'da', 'hoteš', 'biti', 'nekaj', 'poseben', '', '', 'ga', 'je', 'okregati', '', '', 'ali', 'se', 'pretvarjati', '', 'ali', 'kak', '', '']
# ['čopek', 'je', 'šlo', 'že', 'malce', 'ni', 'jok', '', 'zdajec', 'pa', 'se', 'je', 'kar', 'razjeziti', 'ni', 'mamo', '']
# ['', 'če', 'ti', 'pa', 'pravi', '', 'da', 'ni', 'mori', '', '', 'je', 'zagodrnjati', '']
# ['mam', 'si', 'ga', 'je', 'pogledati', 'čist', 'od', 'blizu', 'in', 'se', 'ustrašiti', 'biti', '', 'čopek', '', 'kaj', 'je', 's', 'tvoj', 'tačica', '', 'tu', 'nekaj', 'ni', 'bo', 'prav', '', '']
# ['en', 'taček', 'mlad', 'veverički', 'je', 'biti', 'nenavaden', 'skrivljen', 'in', 'tanek', 'od', 'drug', '', 'zares', '', 'ta', 'veveriček', 'je', 'natanki', 'čutil', '', 'da', 'ni', 'more', 'skakat', '', 'pa', 'če', 'si', 'je', 'še', 'tako', 'želel', '']
# ['kaj', 'pa', 'zdaj', '']
# ['njegov', 'bratec', 'in', 'sester', 'so', 'se', 'že', 'vesel', 'podil', 'po', 'gozd', '', 'kdo', 've', 'kod', '', 'čopek', 'pa', 'je', 'slabe', 'vobje', 'ždel', 'ni', 'veli', 'in', 'grd', 'gledati', 'predse', '', 'in', 'bolj', 'koj', 'ga', 'je', 'mama', 'puhank', 'zaskrbljen', 'ogledovati', '', 'bolj', 'se', 'mu', 'je', 'kremžiti', 'smrček', 'od', 'slabe', 'vobje', '', 'pa', 'kaj', 'ni', 'bi', 'bil', 'mali', 'veveriček', 'slabe', 'vobje', '', 'kak', 'je', 'bil', 'razočaran', '', 'pa', 'še', 'mama', 'puhank', 'se', 'je', 'ni', 'lep', 'začel', 'jokat', '', 'koj', 'ji', 'je', 'postal', 'jasen', '', 'da', 'njen', 'čopek', 'nihče', 'ni', 'bo', 'tak', 'kot', 'druge', 'veverice', '']
# ['', 'nehaj', '', 'mama', '', 'pros', 'ti', '', '', 'je', 'vzklikniti', 'čopek', '', '', 'že', 'tako', 'samo', 'zadost', 'potrt', '', 'zdaj', 'pa', 'še', 'ti', 'solze', 'pretakaš', '', '', 'puhank', 'se', 'je', 'zatekel', 'k', 'svoj', 'teti', '', 'moder', 'repelji', '']
# ['repelj', 'je', 'biti', 'seveda', 'že', 'izvedeti', 'za', 'čopkov', 'nesreč', '', 'šoj', 'je', 'biti', 'dovolj', 'glasen', '–', 'ves', 'gozd', 'je', 'odmevati', 'od', 'njen', 'vreščanji', 'biti', '', 'ste', 'slišal', '', 'ste', 'slišal', '', 'majhen', 'veveriček', 'iz', 'puhankin', 'gnezdi', 'ni', 'more', 'skakat', '', 'kar', 'mu', 'je', 'taček', 'čist', 'drugače', 'zrasti', '', 'le', 'kaj', 'bo', 's', 'ta', 'mladiček', '', '']
# ['star', 'repelj', 'je', 'preprej', 'nahruliti', 'šoj', 'biti', '', 'zase', 'se', 'brigaj', '', 'klepetulj', '', '']
# ['potlej', 'se', 'je', 'resen', 'zagledati', 'v', 'puhankine', 'objokan', 'oči', 'in', 'rekel', 'biti', '', 'daj', 'no', 'puhank', '', 'kdto', 'da', 'je', 'skakanji', 'in', 'plezanji', 'edino', '', 'kar', 'imeti', 'veverice', 'početi', 'ni', 'svet', '', 'pomiri', 'se', 'in', 'daj', 'čas', 'čas', '', 'pa', 'biti', 'videti', '', '']
# ['', 'ampak', 'jaz', 'imeti', 'čopek', 'šratek', '', '', 'je', 'zahlipati', 'puhank', '', '', 'in', 'raven', 'on', 'se', 'je', 'moral', 'to', 'zgodit', '', '']
# ['repelj', 'je', 'zmajal', 'z', 'glav', '']
# ['', 'razume', '', 'da', 'ga', 'imeti', 'šratek', '', 'puhank', '', 'je', 'že', 'tako', '', 'da', 'so', 'majhen', 'mladički', 'ponavad', 'dober', 'ljubek', '', 'ampak', 'nikar', 'ni', 'pretiravaj', 'in', 'nikar', 'se', 'ni', 'cmeri', '', 's', 'ta', 'mu', 'prav', 'nič', 'ni', 'pomagaš', '', 'kolik', 'je', 'veveric', '', 'ki', 'znaj', 'izvrsten', 'skakat', 'in', 'plezat', 'pa', 'nič', 'drug', '', 'zni', 'biti', '', 'da', 'bo', 'imeti', 'raven', 'čopek', 'dovolj', 'čas', '', 'da', 'se', 'nauč', 'čes', 'dober', '', '']
# ['', 'dober', 'je', 'skakanji', '', '', 'je', 'trmoglaviti', 'puhank', '']
# ['', 'no', '', 'če', 'tako', 'misel', '', 'pa', 'nis', 'raven', 'en', 'pometen', '', '', 'se', 'je', 'zadrl', 'repelj', 'in', 'ji', 'pokazati', 'hrbet', '']
# ['puhank', 'se', 'je', 'vrniti', 'ni', 'domač', 'smrek', '', 'koj', 'pa', 'je', 'biti', 'videti', '', 'kak', 'čopek', 'nepremičen', 'ždi', 'ni', 'veli', 'kot', 'kosmat', 'kepic', 'slabe', 'vobje', '', 'se', 'je', 'raje', 'odpraviti', 'nabirat', 'lanski', 'storže', '', 'da', 'se', 'nekolik', 'zamoti', '']
# ['čopek', 'je', 'nazadnji', 'dvigniti', 'glavic', 'in', 'zamežikati', 'v', 'sonce', '', 'ki', 'mu', 'je', 'prijetno', 'grel', 'kožušček', '', 'počasi', 'in', 'previdno', 'seje', 'splazil', 'do', 'konec', 'veti', 'in', 'se', 'razgledal', 'naokrog', '', 'opazilo', 'je', 'pisan', 'gosenic', '', 'ki', 'je', 'lezel', 'po', 'debel', '', 'se', 'nasmehniti', 'mlad', 'kos', '', 'ki', 'je', 'prhniti', 'z', 'druge', 'veti', 'in', 'se', 'spustiti', 'k', 'on', 'in', 'vesel', 'zažvižgati', '']
# ['', 'kdo', 'ti', 'je', 'naučil', 'tako', 'lep', 'žvižgat', '', '', 'je', 'vprašati', 'čopek', '']
# ['', 'nihče', '', '', 'je', 'čivkniti', 'kos', '', '', 'toliko', 'čas', 'samo', 'poskušati', '', 'dokler', 'mi', 'ni', 'uspel', '', 'ta', 'je', 'vse', '', '']
# ['', 'ta', 'je', 'vse', '', '']
# ['', 'ta', 'je', 'vse', '', 'nekatere', 'reč', 'ti', 'uspeti', '', 'druge', 'pač', 'ni', '', 'ampak', 'vsak', 'je', 'treb', 'poskusiti', '', 'veš', '', 'no', '', 'jaz', 'samo', 'se', 'naučil', 'žvižgat', '', 'kaj', 'pa', 'ti', '', '']
# ['', 'ved', 'jaz', '…', 'jaz', 'ni', 'mori', 'skakat', 'in', 'plezat', '', 'zarad', 'tačke', '', 'veš', '', 'ampak', '', 'če', 'se', 'ni', 'bom', 'naučil', 'čes', 'drug', '', 'bom', 'še', 'umrl', 'od', 'dolg', 'čas', '', 'kaj', 'če', 'bi', 'poskusiti', '…', 'na', 'primer', 'peti', '', 'glej', '', 'mogoče', 'se', 'ni', 'bom', 'nihče', 'naučil', 'peti', '', 'ampak', '', 'če', 'ni', 'bom', 'poskusiti', '', 'se', 'pa', 'čist', 'gotov', 'ni', 'bom', 'naučil', '', 'ved', 'kaj', '–', 'kar', 'poskusiti', 'bom', '', '']
# ['čopek', 'je', 'odpreti', 'gobček', 'in', 'spustiti', 'iz', 'sebe', 'hripav', '', 'cvileč', 'glasek', '', 'tako', 'da', 'sta', 'oba', 's', 'kos', 'planiti', 'v', 'sme', '', 'potlej', 'je', 'poskusiti', 'še', 'enkrat', 'in', 'še', 'enkrat', '–', 'in', 'glasen', 'zapel', '–', 'in', 'glej', '', 'njegov', 'glasek', 'je', 'postajati', 'vse', 'bolj', 'čisto', 'in', 'prijeten', '', 'in', 'čopek', 'je', 'skleniti', '', 'da', 'bo', 'poskušati', 'peti', 'vsak', 'dan', '']
# ['tekel', 'so', 'dnevi', 'in', 'veveriček', 'je', 'poskušati', 'to', 'in', 'ono', '', 'naučil', 'se', 'je', 'seštevati', 'in', 'odštevati', 'lešnik', 'v', 'gnezdo', '', 'naučil', 'se', 'je', 'razločevati', 'listi', 'razen', 'dreves', '', 'naučil', 'se', 'je', 'opazovat', 'življenje', 'ptic', '', 'rož', '', 'drevji', '', 'naučil', 'se', 'je', 'napovedovat', 'vreme', 'po', 'veter', '', 'po', 'oblik', 'oblakov', '', 'po', 'cvetov', 'gozden', 'kukavičnik', '', 'in', 'koj', 'je', 'minilo', 'poletji', '', 'ki', 'so', 'ga', 'druge', 'veverice', 'prebile', 'v', 'večen', 'prekopicevanje', 'in', 'divjanji', 'po', 'debel', 'gor', 'in', 'dol', '', 'in', 'spet', 'gor', 'in', 'dol', '–', 'koj', 'je', 'minilo', 'poletji', '', 'je', 'veveriček', 'čopek', 'postal', 'pometen', 'in', 'dober', 'izkušen', 'veveriček', 'v', 'ves', 'gozd', '', 'in', '', 'ni', 'boste', 'verjeti', '', 'kar', 'je', 'nenehen', 'poskušati', 'peti', '', 'se', 'je', 'nazadnji', 'naučil', 'tudi', 'prelep', 'prepevati', '', 'postal', 'je', 'silen', 'priljubljen', 'in', 'vse', 'veverice', 'so', 'hodile', 'k', 'on', 'po', 'nasvet', '', 'celo', 'stara', 'repelj', '', 'ki', 'je', 'biti', 'čist', 'nor', 'nanj', '']
# ['', 'mar', 'ti', 'nis', 'rekel', '', '', 'je', 'nekoč', 'skoraj', 'nadrl', 'ponosen', 'puhanki', '', 'ki', 'je', 'z', 'borov', 'storži', 'skrben', 'skrtačiti', 'čopek', 'kožušček', '', 'da', 'se', 'je', 'svetiti', 'kakor', 'svil', '', 'le', 'kdaj', 'naj', 'bi', 'se', 'bil', 'naš', 'čopek', 'navaditi', 'tako', 'bister', 'razmišljat', '', 'če', 'bi', 'porabiti', 'ves', 'svoj', 'čas', 'za', 'skakanji', 'in', 'divjanje', 'kot', 'druge', 'veverice', '']
# ['čopek', 'se', 'je', 'zamisliti', '', 'druge', 'veverice', 'so', 'se', 'zbrale', 'okol', 'on', '', 'utrujen', 'od', 'plezanji', '', 'tedaj', 'je', 'čopek', 'dvigniti', 'glav', '', 'se', 'zazrl', 'v', 'daljav', 'in', 'tiho', 'spregovoril', '', 'začel', 'je', 'pripovedovati', 'pravo', 'pravcat', 'veveričji', 'pravljic', '', 'ki', 'si', 'jo', 'je', 'kar', 'samo', 'izmisliti', '', 'vsi', 'so', 'napet', 'poslušati', 'in', 'uživati', '', 'veveriček', 'pa', 'je', 'pripovedovati', 'prelep', 'zgodbo', '', 'ki', 'se', 'je', 'začel', 'takole', 'biti']
# ['', 'tih', 'aprilski', 'dežek', 'je', 'rositi', 'ni', 'smrekovji', 'veveričje', 'gaj', '…', '']
# ['1', 'makarovič', '', 'svetlan', '1978', 'biti', 'kosovir', 'ni', 'leteč', 'žlic', '', 'že', 'v', 'začetek', 'strašen', 'srečanje', 'z', 'oblak', '', 'kaj', 'je', 'narediti', 'človeški', 'mladič', ';', 'iz', 'kosovir', 'ni', 'leteč', 'žlic', '', 'ljubljan', 'biti', 'jio', '', 'dinski', 'knjig', 'založb', '']
# ['2', 'makarovič', '', 'svetlan', '2017', 'biti', 'veveriček', 'poseben', 'sorte', '', 'ljubljan', 'biti', 'sonček', '–', 'zvez', 'društev', 'za', 'cerebralen', 'paraliz', 'slovenij', '']
# ['usvv-ususuuuuuuu']
# ['usvv-sususuuuuu/u/u/u/usuuuuuuuuuuuuuuuuuuuuuuuuuu']
# ['usvv-ususuuuuuuu']
# ['usvv-sususuuuuu/u/u/u/usuuuuuuuuuuuuuuuuuuuuuuuuuu']
# ['\ufeff', 'premražen', 'sonce', '', 'svetlan', 'makarovič', '']
# ['', 'kak', 'svetle', 'so', 'zvezde', 'nocoj', '', '', 'je', 'nek', 'jasne', 'jesenski', 'noč', 'vzkliknit', 'veverica', '', 'ki', 'ni', 'moči', 'spat', '']
# ['', 'in', 'kolik', 'jih', 'je', '', '', 'je', 'sanjav', 'rekel', 'njen', 'sestrična', '', 'ki', 'tudi', 'ni', 'moči', 'spat', '', '', 'poglej', 'tisti', 'svetel', 'zvezdo', 'tamle', 'nad', 'smrek', '', 'tako', 'vesel', 'jaz', 'mežik', '', '']
# ['mežikajoč', 'zvezda', 'ti', 'daleč', 'v', 'neznanski', 'velik', 'vesolj', 'pa', 'je', 'biti', 'majhen', 'sončece', '', 'okol', 'kateri', 'je', 'počasi', 'krožiti', 'pet', 'majhen', 'zelen', 'planetov', '']
# ['', 'ali', 'ni', 'bi', 'moči', 'sijat', 'malo', 'svetlej', '', '', 'je', 'zagodrnjati', 'velik', 'planet', '', '', 'saj', 'komaj', 'vid', '', 'kod', 'mora', 'krožit', '', 'ali', 'pa', 'mogoče', 'hoteš', '', 'da', 'bi', 'zašel', 's', 'poti', 'in', 'se', 'izgubiti', 'v', 'vesolj', 'samo', 'zato', '', 'kar', 'si', 'ti', 'zaspan', '', '']
# ['', 'res', '', 'kakšen', 'sonce', 'pa', 'si', '', '', 'se', 'je', 'razburjati', 'drugi', 'planet', '', '', 'na', 'meni', 'je', 'že', 'pošten', 'hladen', '', '']
# ['', 'sij', 'malo', 'topel', '', 'pros', '', '', 'je', 'rekel', 'tretji', 'planet', '', '', 'ali', 'pa', 'bom', 'odšel', 'in', 'si', 'poiskati', 'pošten', 'velik', 'sonce', '', 'ki', 'ni', 'bo', 'samo', 'brlel', 'tako', 'kot', 'ti', '', 'ampak', 'pošten', 'svetiti', 'in', 'grel', '', '']
# ['', 'da', 'moram', 'imeti', 'raven', 'mi', 'tako', 'klavrn', 'sonce', '', '', 'se', 'je', 'jezil', 'četrti', 'planet', '']
# ['peti', '', 'majhen', 'planetek', 'pa', 'je', 'ni', 'svoj', 'kroženje', 'poskakovati', '', 'da', 'bi', 'se', 'ogrel', '', 'ko', 'je', 'slišal', 'godrnjanje', 'svoj', 'bratov', '', 'je', 'pomežikniti', 'sonec', 'in', 'rekel', 'biti']
# ['', 'kar', 'dober', 'si', '', 'sonček', '', 'nikar', 'jih', 'ni', 'poslušaj', '', '']
# ['malo', 'sonce', 'je', 'globok', 'vzdihnit', 'in', 'reklo', 'biti']
# ['', 'tako', 'rad', 'bi', 'svetiti', 'in', 'grel', 'močen', 'kar', 'se', 'le', 'da', '', 'ampak', 'tukaj', 'noter', 'me', 'tako', 'zebe', '', 'da', 'kar', 'trepeč', '', '']
# ['', 'neumnost', '', '', 'je', 'zarohnel', 'prvi', 'planet', '']
# ['', 'še', 'nihče', 'nis', 'slišal', 'čes', 'tak', '', '', 'je', 'rekel', 'drugi', 'planet', '']
# ['', 'sonec', 'vendar', 'ni', 'more', 'zebsti', '', '', 'se', 'je', 'razhuditi', 'tretji', '', '', 'drajb', 'se', 'norčuješ', 'iz', 'nas', '', '']
# ['', 'ni', 'norčev', 'se', '', '', 'je', 'reklo', 'sončece', '', '', 'sij', 'in', 'grej', 'kolikor', 'mori', '', 'ampak', 'čimbolj', 'grej', 'druge', '', 'bolj', 'me', 'zebe', '', 'znotraj', 'samo', 'temno', 'in', 'že', 'zdavnaj', 'ohrajen', '', 'veste', '', '']
# ['', 'dober', 'izgovor', '', 'tudi', 'če', 'ga', 'komet', 'ni', 'rep', 'prinese', '', '', 'se', 'je', 'smejati', 'četrti', 'planet', '']
# ['mali', '', 'peti', 'planet', 'pa', 'se', 'je', 'zares', 'razjeziti', '', 'tako', 'da', 'se', 'je', 'ni', 'njegov', 'površin', 'odpreti', 'vulkan', 'in', 'začel', 'sikat', 'vroč', 'paro', '']
# ['', 'nehaj', 'no', '', 'to', 'me', 'žgečki', '', '', 'je', 'ukazal', 'mali', 'planet', 'vulkan', '', 'vulkan', 'je', 'še', 'malo', 'zasikati', '', 'potem', 'pa', 'se', 'umiriti', '', 'planetek', 'je', 'za', 'klical', 'svoj', 'brat', 'biti']
# ['', 'sram', 'naj', 'vas', 'bo', '', 'sploh', 'nisti', 'vreden', 'nit', 'en', 'sončen', 'žarka', '', 'če', 'ti', 'naš', 'sonce', 'ni', 'zadost', 'dobro', '', 'pa', 'itdite', 'druga', '', 'jaz', '', 'sonček', '', 'samo', 'prav', 'zadovoljen', 's', 'tabo', '', 'takole', 'malo', 'poskoč', '', 'vid', '', 'pa', 'mi', 'je', 'raven', 'prav', 'topel', '', '']
# ['ta', 'besede', 'so', 'mali', 'sonec', 'tako', 'dobro', 'dele', '', 'da', 'mu', 'je', 'začel', 'postajati', 'topel', 'okol', 'srci', '', 'kolikor', 'je', 'moči', '', 'je', 'začel', 'greti', 'in', 'sijat', '', 'štirje', 'planet', 'so', 'se', 'zdaj', 'še', 'bolj', 'razjeziti', '']
# ['', 'no', '', 'vid', '', 'saj', 'lahko', 'bolje', 'sij', '', 'lenoba', '', '', 'je', 'zarohnel', 'prvi', 'planet', '', '', 'še', 'bolj', 'se', 'potrud', '', 'no', '', 'no', '', 'bo', 'kaj', '', '']
# ['sončece', 'se', 'je', 'spet', 'zmračiti', '', 'komaj', 'da', 'je', 'še', 'brlel', 'in', 'spet', 'je', 'trepetal', 'od', 'mraz', '', 'majhen', 'planetek', 'mu', 'je', 'peti', 'vesel', 'pesmice', '', 'on', 'sonce', 'ga', 'ni', 'slišati', '', 'v', 'njegov', 'notranjost', 'je', 'začel', 'nekaj', 'kapljat', '', 'tink', 'tonk', '', 'tink', 'tonk', '', 'so', 'padale', 'solze', 'v', 'srce', '', 'sončev', 'površin', 'je', 'postal', 'zelenkast', '', 'nato', 'modrikast', '']
# ['', 'ugasnil', 'bo', '', '', 'so', 'zakričati', 'planet', '', 'in', 'prvi', 'štirje', 'so', 'se', 'v', 'hip', 'odločiti', 'in', 'jo', 'pobrisati', 'kdov', 'kaj', '', 'mogoče', 'so', 'našti', 'kakšen', 'sonce', '', 'mogoče', 'tudi', 'ni', '', 'mali', 'planet', 'pa', 'se', 'je', 'primakniti', 'bliže', 'sonec', 'in', 'še', 'samo', 'zajokati', '']
# ['sonce', 'je', 'malo', 'prisluhnit', ';', 'šele', 'zdaj', 'je', '', 'opaziti', '', 'da', 'ni', 'čist', 'samo', '']
# ['', 'ti', 'si', 'še', 'tukaj', '', 'mali', 'planetek', '', '', 'je', 'vprašati', '', '', 'in', 'zakaj', 'jočeš', '', '']
# ['', 'hud', 'mi', 'je', 'zate', '', 'sonček', '', '', 'je', 'rekel', 'planetek', '', '', 'in', 'zebe', 'me', '', '']
# ['v', 'hip', 'je', 'sonce', 'ni', 'vso', 'moč', 'zažarel', 'in', 'obsijati', 'mali', 'planet', 's', 'čudovit', 'svetel', 'in', 'vroč', 'žarki', '']
# ['', 'kak', 'samo', 'srečen', '', '', 'je', 'zaklical', 'mali', 'planet', 'in', 'živo', 'zazelenel', '']
# ['', 'kak', 'samo', 'srečen', '', '', 'je', 'zaklicati', 'sonce', '', 'ki', 'ga', 'ni', 'nihče', 'več', 'zeblo', 'pri', 'srcu', '', 'in', 'vesel', 'je', 'mežikati', 'ni', 'vse', 'stran', '']
# ['daleč', 'daleč', 'stran', '', 'ni', 'planet', 'zemelj', '', 'pa', 'sta', 'se', 'v', 'mrzel', 'jesenski', 'noč', 'stiskal', 'dve', 'droben', 'veveric', 'stisnil', 'skupaj', 'in', 'strmel', 'v', 'zvezdnat', 'nebo', '']
# BOOK RELEVANCE...
# BOOK RELEVANCE...

# %%
positiveLabel = 'Yes'

# Does not work with additional features
'''
naive_bayes = MultinomialNB()
naive_bayes.fit( X_train_cv, y_train )
predictions = naive_bayes.predict( X_test_cv )

print( 'Accuracy score of Naive Bayes: ', accuracy_score( y_test, predictions ) )
print( 'Precision score of Naive Bayes: ', precision_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'Recall score of Naive Bayes: ', recall_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'F1 score of Naive Bayes:', f1_score( y_test, predictions, pos_label = positiveLabel ) )
print()


# cm = confusion_matrix( y_test, predictions )
# print( cm )
# df_cm = pd.DataFrame( cm, range( 2 ), range( 2 ) )
# plt.figure(figsize=(10,7))
# sn.set(font_scale=1.4) # for label size
# sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
# plt.imshow( cm )
# plt.show()


# probs = naive_bayes.predict_proba( X_test_cv )
probs = naive_bayes.predict_proba( X_test_cv )
preds = probs[ :, 1 ]
fpr, tpr, threshold = roc_curve( y_test, preds, pos_label = positiveLabel )
roc_auc = auc( fpr, tpr )
auc_nb = roc_auc

plt.title( 'Receiver Operating Characteristic' )
plt.plot( fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc )
plt.legend( loc = 'lower right') 
plt.plot( [ 0, 1 ], [ 0, 1 ], 'r--' )
plt.xlim( [ 0, 1 ] )
plt.ylim( [ 0, 1 ] )
plt.ylabel( 'True Positive Rate' )
plt.xlabel( 'False Positive Rate' )
plt.show()
'''
# Out:
# '\nnaive_bayes = MultinomialNB()\nnaive_bayes.fit( X_train_cv, y_train )\npredictions = naive_bayes.predict( X_test_cv )\n\nprint( \'Accuracy score of Naive Bayes: \', accuracy_score( y_test, predictions ) )\nprint( \'Precision score of Naive Bayes: \', precision_score( y_test, predictions, pos_label = positiveLabel ) )\nprint( \'Recall score of Naive Bayes: \', recall_score( y_test, predictions, pos_label = positiveLabel ) )\nprint( \'F1 score of Naive Bayes:\', f1_score( y_test, predictions, pos_label = positiveLabel ) )\nprint()\n\n\n# cm = confusion_matrix( y_test, predictions )\n# print( cm )\n# df_cm = pd.DataFrame( cm, range( 2 ), range( 2 ) )\n# plt.figure(figsize=(10,7))\n# sn.set(font_scale=1.4) # for label size\n# sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size\n# plt.imshow( cm )\n# plt.show()\n\n\n# probs = naive_bayes.predict_proba( X_test_cv )\nprobs = naive_bayes.predict_proba( X_test_cv )\npreds = probs[ :, 1 ]\nfpr, tpr, threshold = roc_curve( y_test, preds, pos_label = positiveLabel )\nroc_auc = auc( fpr, tpr )\nauc_nb = roc_auc\n\nplt.title( \'Receiver Operating Characteristic\' )\nplt.plot( fpr, tpr, \'b\', label = \'AUC = %0.2f\' % roc_auc )\nplt.legend( loc = \'lower right\') \nplt.plot( [ 0, 1 ], [ 0, 1 ], \'r--\' )\nplt.xlim( [ 0, 1 ] )\nplt.ylim( [ 0, 1 ] )\nplt.ylabel( \'True Positive Rate\' )\nplt.xlabel( \'False Positive Rate\' )\nplt.show()\n'

# %%
lrRelevant = LogisticRegression()
lrRelevant.fit( X_train_cv, y_train )
predictions = lrRelevant.predict( X_test_cv )

print( 'Accuracy score of Logistic Regression: ', accuracy_score( y_test, predictions ) )
print( 'Precision score of Logistic Regression: ', precision_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'Recall score of Logistic Regression: ', recall_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'F1 score of Logistic Regression:', f1_score( y_test, predictions, pos_label = positiveLabel ) )

probs = lrRelevant.predict_proba( X_test_cv )
preds = probs[ :, 1 ]
fpr, tpr, threshold = roc_curve( y_test, preds, pos_label = positiveLabel )
roc_auc = auc( fpr, tpr )
print('AUC = ', roc_auc)
auc_lr = roc_auc

plt.title( 'Receiver Operating Characteristic' )
plt.plot( fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc )
plt.legend( loc = 'lower right') 
plt.plot( [ 0, 1 ], [ 0, 1 ], 'r--' )
plt.xlim( [ 0, 1 ] )
plt.ylim( [ 0, 1 ] )
plt.ylabel( 'True Positive Rate' )
plt.xlabel( 'False Positive Rate' )
plt.show()
# Out:
# Accuracy score of Logistic Regression:  0.8519774011299435
# Precision score of Logistic Regression:  0.8410596026490066
# Recall score of Logistic Regression:  0.7537091988130564
# F1 score of Logistic Regression: 0.7949921752738653
# AUC =  0.9204390391821351

# %%
svm = SVC( kernel = 'linear', C = 1, probability = True )
svm.fit( X_train_cv, y_train )
predictions = svm.predict( X_test_cv )

print( 'Accuracy score of SVM: ', accuracy_score( y_test, predictions ) )
print( 'Precision score of SVM: ', precision_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'Recall score of SVM: ', recall_score( y_test, predictions, pos_label = positiveLabel ) )
print( 'F1 score of SVM:', f1_score( y_test, predictions, pos_label = positiveLabel ) )

probs = svm.predict_proba( X_test_cv )
preds = probs[ :, 1 ]
fpr, tpr, threshold = roc_curve( y_test, preds, pos_label = positiveLabel )
roc_auc = auc( fpr, tpr )
auc_svm = roc_auc

plt.title( 'Receiver Operating Characteristic' )
plt.plot( fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc )
plt.legend( loc = 'lower right') 
plt.plot( [ 0, 1 ], [ 0, 1 ], 'r--' )
plt.xlim( [ 0, 1 ] )
plt.ylim( [ 0, 1 ] )

plt.ylabel( 'True Positive Rate' )
plt.xlabel( 'False Positive Rate' )
plt.show()
# Out:
# Accuracy score of SVM:  0.8610169491525423
# Precision score of SVM:  0.8386075949367089
# Recall score of SVM:  0.7863501483679525
# F1 score of SVM: 0.8116385911179173

# %%
y_train = [ data[ 'CategoryBroad'][ i ] for i in X_trainO.index ]
y_test = [ data[ 'CategoryBroad'][ i ] for i in X_testO.index ]

labels = set( [ value for value in data[ 'CategoryBroad'] ] )
for label in labels:
    print( 'Number of examples in category {0}: {1}'.format( label, len( X_trainO[ ( data[ 'CategoryBroad' ] == label ) ] ) ) )
# Out:
# Number of examples in category S: 31
# Number of examples in category O: 206
# Number of examples in category D: 899
# Number of examples in category M: 143
# Number of examples in category I: 312
# Number of examples in category C: 1062

# %%
cv = FeatureUnion([
    ('tfidf', TfidfVectorizer(tokenizer = lambda x : x, preprocessor = lambda x : x, analyzer = 'word', sublinear_tf=True, max_df=0.5)),
    ('feat', MeasureFeatures('category_broad'))
                  ])

X_train_cv = cv.fit_transform( lemmasTrain )
X_test_cv = cv.transform( lemmasTest )
# Out:
# TYPE...
# TYPE...

# %%
#Does not work with additional features
'''naive_bayes = MultinomialNB()
naive_bayes.fit( X_train_cv, y_train )
predictions = naive_bayes.predict( X_test_cv )
print( 'Accuracy score of Naive Bayes: ', accuracy_score( y_test, predictions ) )
print( 'AUC of Naive Bayes:', auc_nb)
print( 'F1 score of Naive Bayes:', f1_score( y_test, predictions, average = 'weighted' ) )
print()'''

lr = LogisticRegression()
lr.fit( X_train_cv, y_train )
predictions = lr.predict( X_test_cv )
print( 'Accuracy score of Logistic Regression: ', accuracy_score( y_test, predictions ) )
print( 'AUC of Logistic Regression:', auc_lr)
print( 'F1 score of Logistic Regression:', f1_score( y_test, predictions, average = 'weighted' ) )
print()

svm = SVC( kernel = 'linear', C = 1, probability = True )
svm.fit( X_train_cv, y_train )
predictions = svm.predict( X_test_cv )
print( 'Accuracy score of SVM: ', accuracy_score( y_test, predictions ) )
print( 'AUC of SVM:', auc_svm)
print( 'F1 score of SVM:', f1_score( y_test, predictions, average = 'weighted' ) )
print()
# Out:
# C:\Users\Tim\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy score of Logistic Regression:  0.7254237288135593
# AUC of Logistic Regression: 0.9204390391821351
# F1 score of Logistic Regression: 0.7156738608919194
#
# Accuracy score of SVM:  0.7389830508474576
# AUC of SVM: 0.9175204141306939
# F1 score of SVM: 0.7328729058053067

# %%
lemmasIMap = parseLemmas( DATA_DIR + 'IMap.output' ) #lemmatize( data[ 'Message' ], 'IMap' )
index = int( len( lemmasIMap ) * 0.7 )
X_train, y_train = lemmasIMap[ 0 : index ], data[ 'Book relevance' ][ 0 : index ]
X_test, y_test = lemmasIMap[ index : ], data[ 'Book relevance' ][ index : ]

# print( len( [ x for x in y_test if x == 'Yes' ] ) )
# print( len( [ x for x in y_test if x == 'No' ] ) )
# print()
# print( len( [ x for x in y_train if x == 'Yes' ] ) )
# print( len( [ x for x in y_train if x == 'No' ] ) )


cv = CountVectorizer( tokenizer = lambda x : x, preprocessor = lambda x : x, analyzer = 'word', ngram_range = ( 1, 3 ) )

X_train_cv = cv.fit_transform( X_train )
X_test_cv = cv.transform( X_test )

# modelRelevant = LogisticRegression()
modelRelevant = SVC( kernel = 'linear', C = 1, probability = True )
modelRelevant.fit( X_train_cv, data[ 'Book relevance' ][ 0 : index ] )

# Cross validation
clf = Pipeline( [ ( 'vect', cv ), ( 'svm', modelRelevant ) ] )
scores = cross_validate( clf, lemmasIMap, data[ 'Book relevance' ], cv = 5, scoring = [ 'accuracy', 'f1_weighted' ] )
# print( 'Accuracy scores for Relevant model', scores[ 'test_accuracy' ] )
# print( 'F1 scores for Relevant model', scores[ 'test_f1_weighted' ] )
print( 'Average accuracy for relevant model', mean( scores[ 'test_accuracy' ] ) )
print( 'Average F1 score for relevant model', mean( scores[ 'test_f1_weighted' ] ) )
print()

modelCategory = LogisticRegression()
# modelCategory = SVC( kernel = 'linear', C = 1, probability = True )
modelCategory.fit( X_train_cv, data[ 'CategoryBroad' ][ 0 : index ] )

# Cross validation
clf = Pipeline( [ ( 'vect', cv ), ( 'svm', modelCategory ) ] )
scores = cross_validate( clf, lemmasIMap, data[ 'CategoryBroad' ], cv = 5, scoring = [ 'accuracy', 'f1_weighted' ] )
# print( 'Accuracy scores for Category model', scores[ 'test_accuracy' ] )
# print( 'F1 scores for Category model', scores[ 'test_f1_weighted' ] )
print( 'Average accuracy for Category model', mean( scores[ 'test_accuracy' ] ) )
print( 'Average F1 score for Category model', mean( scores[ 'test_f1_weighted' ] ) )
print()

batchSize = 10
relevance = []
softRelevance = [ 'D', 'S', 'M' ]
for i in range( 0, len( X_test ), batchSize ):
    batch = X_test[ i : i + batchSize ]
    batch_cv = cv.transform( batch )
    predictionsRelevant = modelRelevant.predict( batch_cv )
    batchYes = 0
    batchNo = 0
    for j in range( 0, len( predictionsRelevant ) ):
        if predictionsRelevant[ j ] == 'Yes':
#             relevance.append( 'Yes' )
                batchYes += 1
        else:
            category = modelCategory.predict( batch_cv[ j ] )
#             relevance.append( 'Yes' if category == 'D' or category == 'S' or category == 'M' else 'No' )
            if category in softRelevance:
                batchYes += 1
            else:
                batchNo += 1
    relevance.append( 'Yes' if batchYes >= batchNo else 'No' )
for i in range( 0, len( relevance ), 5 ):
    batch = relevance[ i : i + 5 ]
    if all( [ x == 'No' for x in batch ] ):
        print( 'The teacher must intervene' )
# Out:
# Average accuracy for relevant model 0.8117613214105914
# Average F1 score for relevant model 0.8070163017976282
#
# Average accuracy for Category model 0.671865285802188
# Average F1 score for Category model 0.6517141909409461
#
# The teacher must intervene
# The teacher must intervene
# The teacher must intervene
